# %% [markdown]
# # Introduccion a Pandas

# %% [markdown]
# ![pandas.png](attachment:pandas.png)

# %% [markdown]
# Pandas es una herramienta de manipulación de datos de alto nivel desarrollada por Wes McKinney. Es construido con el paquete Numpy y su estructura de datos clave es llamada el DataFrame. El DataFrame te permite almacenar y manipular datos tabulados en filas de observaciones y columnas de variables

# %%
import pandas as pd

# %%
# Importamos inicialmente las librerias de Python (Pandas)
import pandas as pd
# cargamos un dataframe, leyendo un CSV
df = pd.read_csv("C:\\Users\\jespitiaa\\Documents\\GitHub\\data_science_and_big_data_I\\input\\COVID-19_Daily_Counts_of_Cases.csv"
                 ,delimiter=','
                 ,nrows = 1000)
# Listamos los 5 primeros registros
df.head()
# Out:
#          DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 0  02/29/2020 12:00:00 AM           1                  11            0
# 1  03/01/2020 12:00:00 AM           0                   4            0
# 2  03/02/2020 12:00:00 AM           0                  21            0
# 3  03/03/2020 12:00:00 AM           1                  20            0
# 4  03/04/2020 12:00:00 AM           5                  22            0

# %%
# Otra forma de cargar el CSV en un dataframe, con otro estilo rut
df2 = pd.read_csv("C:/Users/jespitiaa/Documents/GitHub/data_science_and_big_data_I/input/COVID-19_Daily_Counts_of_Cases.csv")
# Imprimimos 10 registros
df2.head(10)
# Out:
#          DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 0  02/29/2020 12:00:00 AM           1                  11            0
# 1  03/01/2020 12:00:00 AM           0                   4            0
# 2  03/02/2020 12:00:00 AM           0                  21            0
# 3  03/03/2020 12:00:00 AM           1                  20            0
# 4  03/04/2020 12:00:00 AM           5                  22            0
# 5  03/05/2020 12:00:00 AM           3                  20            0
# 6  03/06/2020 12:00:00 AM           8                  18            0
# 7  03/07/2020 12:00:00 AM           7                  15            0
# 8  03/08/2020 12:00:00 AM          21                  17            0
# 9  03/09/2020 12:00:00 AM          57                  49            0

# %%
# Imprimimos los ultimos 5 registros de nuestro Dataframe
df.tail()
# Out:
#            DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 214  09/30/2020 12:00:00 AM         514                  40            5
# 215  10/01/2020 12:00:00 AM         455                  31            3
# 216  10/02/2020 12:00:00 AM         304                  35            3
# 217  10/03/2020 12:00:00 AM          75                   3            0
# 218  10/04/2020 12:00:00 AM          12                   0            0

# %%
# Podemos listar los N ultimos registros
df.tail(10)
# Out:
#            DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 209  09/25/2020 12:00:00 AM         422                  39            3
# 210  09/26/2020 12:00:00 AM         253                  21            6
# 211  09/27/2020 12:00:00 AM         354                  29            2
# 212  09/28/2020 12:00:00 AM         412                  36            4
# 213  09/29/2020 12:00:00 AM         635                  41            7
# 214  09/30/2020 12:00:00 AM         514                  40            5
# 215  10/01/2020 12:00:00 AM         455                  31            3
# 216  10/02/2020 12:00:00 AM         304                  35            3
# 217  10/03/2020 12:00:00 AM          75                   3            0
# 218  10/04/2020 12:00:00 AM          12                   0            0

# %%
# Si queremos Reordenar el datafrma usamos la siguiente sentencia
df.sample(frac = 1)
# Out:
#            DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 37   04/06/2020 12:00:00 AM        6365                1724          575
# 80   05/19/2020 12:00:00 AM        1004                 229           55
# 124  07/02/2020 12:00:00 AM         418                  49           24
# 19   03/19/2020 12:00:00 AM        3707                 560           24
# 58   04/27/2020 12:00:00 AM        2290                 448          271
# ..                      ...         ...                 ...          ...
# 128  07/06/2020 12:00:00 AM         434                  48           16
# 87   05/26/2020 12:00:00 AM        1053                 168           38
# 155  08/02/2020 12:00:00 AM         134                  28            2
# 119  06/27/2020 12:00:00 AM         207                  42           21
# 201  09/17/2020 12:00:00 AM         348                  27            3
#
# [219 rows x 4 columns]

# %%
# Podemos guardar el Dataframe desordenado en Otro Dataframe
dfDisorder = df.sample(frac=1)
# Listamos el Dataframe desordenado
dfDisorder.head()
# Out:
#            DATE_OF_INTEREST  CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT
# 53   04/22/2020 12:00:00 AM        3462                 600          313
# 27   03/27/2020 12:00:00 AM        5120                1403          218
# 100  06/08/2020 12:00:00 AM         451                  81           40
# 199  09/15/2020 12:00:00 AM         342                  27            3
# 49   04/18/2020 12:00:00 AM        2172                 676          390

# %% [markdown]
# Si queremos listar los nombres de las columnas del Dataframe, se realiza mediante la siguiente sentencia

# %%
# Listamos las columnas del Dataframe
df.columns
# Out:
# Index(['DATE_OF_INTEREST', 'CASE_COUNT', 'HOSPITALIZED_COUNT', 'DEATH_COUNT'], dtype='object')

# %%
# Podemos listar los valores de una sola columna 
df.DATE_OF_INTEREST
# Out:
# 0      02/29/2020 12:00:00 AM
# 1      03/01/2020 12:00:00 AM
# 2      03/02/2020 12:00:00 AM
# 3      03/03/2020 12:00:00 AM
# 4      03/04/2020 12:00:00 AM
#                 ...
# 214    09/30/2020 12:00:00 AM
# 215    10/01/2020 12:00:00 AM
# 216    10/02/2020 12:00:00 AM
# 217    10/03/2020 12:00:00 AM
# 218    10/04/2020 12:00:00 AM
# Name: DATE_OF_INTEREST, Length: 219, dtype: object

# %% [markdown]
# Para listar los tipos de datos de las columnas de los dataframes, usamos la siguiente sentencia

# %%
df.dtypes
# Out:
# DATE_OF_INTEREST      object
# CASE_COUNT             int64
# HOSPITALIZED_COUNT     int64
# DEATH_COUNT            int64
# dtype: object

# %% [markdown]
# Podemos imprimir todos los valores del dataframe en un Array.
# Suele ser util para operaciones entre matrices

# %%
df.values
# Out:
# array([['02/29/2020 12:00:00 AM', 1, 11, 0],
#        ['03/01/2020 12:00:00 AM', 0, 4, 0],
#        ['03/02/2020 12:00:00 AM', 0, 21, 0],
#        ['03/03/2020 12:00:00 AM', 1, 20, 0],
#        ['03/04/2020 12:00:00 AM', 5, 22, 0],
#        ['03/05/2020 12:00:00 AM', 3, 20, 0],
#        ['03/06/2020 12:00:00 AM', 8, 18, 0],
#        ['03/07/2020 12:00:00 AM', 7, 15, 0],
#        ['03/08/2020 12:00:00 AM', 21, 17, 0],
#        ['03/09/2020 12:00:00 AM', 57, 49, 0],
#        ['03/10/2020 12:00:00 AM', 70, 63, 0],
#        ['03/11/2020 12:00:00 AM', 155, 90, 1],
#        ['03/12/2020 12:00:00 AM', 357, 94, 0],
#        ['03/13/2020 12:00:00 AM', 619, 157, 0],
#        ['03/14/2020 12:00:00 AM', 642, 157, 2],
#        ['03/15/2020 12:00:00 AM', 1036, 191, 5],
#        ['03/16/2020 12:00:00 AM', 2121, 316, 8],
#        ['03/17/2020 12:00:00 AM', 2452, 356, 8],
#        ['03/18/2020 12:00:00 AM', 2973, 470, 20],
#        ['03/19/2020 12:00:00 AM', 3707, 560, 24],
# ...

# %% [markdown]
# ## Filtrar datos en Python

# %% [markdown]
# Cargamos inicialmente un archivo csv en un Dataframe

# %%
dfUdemy = pd.read_csv("C:/Users/jespitiaa/Documents/GitHub/data_science_and_big_data_I/input/udemy_courses_financial.csv")
# Imprimimos los primeros 10 registros
dfUdemy.head(10)
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
# 5  1208634  Microsoft Power BI - A Complete Introduction [...
# 6   864146  Agile Crash Course: Agile Project Management; ...
# 7   321410  Beginner to Pro in Excel: Financial Modeling a...
# 8   673654  Become a Product Manager | Learn the Skills & ...
# 9  1653432      The Business Intelligence Analyst Course 2020
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# ...

# %%
# Listamos en un array las columnas que contiene ese array
dfUdemy.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
# Listamos la cantidad de valores por columnas del Dataframe
dfUdemy.count()
# Out:
# id                              13608
# title                           13608
# url                             13608
# is_paid                         13608
# num_subscribers                 13608
# avg_rating                      13608
# avg_rating_recent               13608
# rating                          13608
# num_reviews                     13608
# is_wishlisted                   13608
# num_published_lectures          13608
# num_published_practice_tests    13608
# created                         13608
# published_time                  13608
# discount_price__amount          12205
# discount_price__currency        12205
# discount_price__price_string    12205
# price_detail__amount            13111
# price_detail__currency          13111
# price_detail__price_string      13111
# dtype: int64

# %%
# Listamos el tamaño en Bytes del Datafrma
dfUdemy.size
# Out:
# 272160

# %%
# Obtenemos los 10 primeros registros de una columna en especifica
dfUdemy["title"].head(10)
# Out:
# 0    The Complete SQL Bootcamp 2020: Go from Zero t...
# 1    Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2               PMP Exam Prep Seminar -  PMBOK Guide 6
# 3           The Complete Financial Analyst Course 2020
# 4    An Entire MBA in 1 Course:Award Winning Busine...
# 5    Microsoft Power BI - A Complete Introduction [...
# 6    Agile Crash Course: Agile Project Management; ...
# 7    Beginner to Pro in Excel: Financial Modeling a...
# 8    Become a Product Manager | Learn the Skills & ...
# 9        The Business Intelligence Analyst Course 2020
# Name: title, dtype: object

# %% [markdown]
# Si queremos obtener el dataframe filtrado por una columna en especifico, lo realizamos con la siguiente sentencia

# %%
# Filtramos en un nuevo dataframe los cursos que tenga un numero de conferencias publicadas mayor a 100
dfUdemy[dfUdemy["num_published_lectures"] > 100]
# Out:
#             id                                              title  \
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 5      1208634  Microsoft Power BI - A Complete Introduction [...
# 7       321410  Beginner to Pro in Excel: Financial Modeling a...
# 8       673654  Become a Product Manager | Learn the Skills & ...
# ...        ...                                                ...
# 12884  3248636                                  Auxiliar Contable
# 12978  1322248  تحرر الآن من أكثر الأخطاء التي تمنعك من دخول ع...
# 13064  2976544  Cartões de Crédito - Como Ter os Melhores Bene...
# 13189  2648662  Curso de Inversiones: Aprende a Invertir en Fo...
# 13232  3203182  हिन्दी में टैली ईआरपी 9 जीएसटी पूर्ण पाठ्यक्रम...
#
#                                                      url  is_paid  \
# 2                            /course/pmp-pmbok6-35-pdus/     True
# ...
